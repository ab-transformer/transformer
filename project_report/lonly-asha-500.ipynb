# %%
import os
os.chdir('..')

# %%
from hpopt_eval import eval_hpopt

# %%
eval_hpopt('lonly-asha-500')
# Out:
# 100%|██████████| 476/476 [01:21<00:00,  5.87it/s]
# Number of experiment: 476.
# Best valid mae: 0.9046.
# /opt/conda/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:50: RuntimeWarning: Missing Tags: logs/csv/1a88430d7db24720bce09470a522c668/version_0/hparams.yaml.
#   warnings.warn(*args, **kwargs)
# /opt/conda/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:50: RuntimeWarning: Missing Tags: logs/csv/4652aa2d13cc4618b6c022db3ed7a9a5/version_0/hparams.yaml.
#   warnings.warn(*args, **kwargs)
