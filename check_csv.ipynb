# %%
import pandas as pd

import mutils

df = pd.read_csv(mutils.csv_dir / "3335213fa8744c3395be0ad8f7d64a4b" / "version_0" / "metrics.csv")
df = mutils.get_epoch_info(df)

# %%
df
# Out:
#     epoch  train_1mae_epoch  valid_1mae  \
# 0       0          0.632032    0.739867
# 1       1          0.707605    0.803495
# 2       2          0.751033    0.842614
# 3       3          0.785417    0.859115
# 4       4          0.810044    0.868614
# 5       5          0.828414    0.877360
# 6       6          0.842258    0.881333
# 7       7          0.852918    0.883271
# 8       8          0.860753    0.885516
# 9       9          0.867077    0.887424
# 10     10          0.871711    0.888358
# 11     11          0.875133    0.890813
# 12     12          0.877989    0.890504
# 13     13          0.880521    0.891479
# 14     14          0.882718    0.892663
# 15     15          0.884313    0.893074
# 16     16          0.886386    0.892691
# 17     17          0.887715    0.894887
# 18     18          0.888689    0.895829
# 19     19          0.890112    0.895399
# 20     20          0.890359    0.895765
# 21     21          0.890983    0.896209
# ...
